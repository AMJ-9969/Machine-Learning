# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/amjdrive')
# Out:
# Drive already mounted at /content/amjdrive; to attempt to forcibly remount, call drive.mount("/content/amjdrive", force_remount=True).

# %%
df=pd.read_csv('/content/amjdrive/MyDrive/Phython/car speed.csv')

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         NaN    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
df.experience
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     NaN
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
exm_fit=df.experience.median()

# %%
exm_fit
# Out:
# 5.0

# %%
df.experience= df.experience.fillna(exm_fit)

# %%
df.experience
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     5.0
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         5.0    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['speed','car_age','experience',]],df.risk)
# Out:
# LinearRegression()

# %%
reg.predict([[160,10,5]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([71.37146872])

# %%
reg.coef_
# Out:
# array([ 0.33059217,  1.61053246, -6.20772074])

# %%
reg.intercept_
# Out:
# 33.41000091043588

# %%
0.33059217*160+1.61053246*10+5*-6.20772074+33.41000091043588
# Out:
# 71.37146901043589
